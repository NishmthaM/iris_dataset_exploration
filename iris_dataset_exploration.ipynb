# %% [markdown]
# <a href="https://colab.research.google.com/github/NishmthaM/iris_dataset_exploration/blob/main/iris_dataset_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                        # numerical computaion
import pandas as pd                       # load dataset
import matplotlib.pyplot as plt           # data visualization
import seaborn as sns                     # data visualization
from sklearn.datasets import load_iris    # from scikit_learn lib

# %%
# load iris dataset

iris=load_iris(as_frame=True)

# %%
print(type(iris))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
df=iris.frame

# %%
print(iris)
# Out:
# {'data':      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.shape # gives the no. of rows and columns
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
target_names=dict(enumerate(iris.target_names))

# %%
print(target_names)
# Out:
# {0: np.str_('setosa'), 1: np.str_('versicolor'), 2: np.str_('virginica')}

# %%
df['Species']= df["target"].map(target_names) # mapping the target with the target names

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target Species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target    Species
# 145       2  virginica
# 146       2  virginica
# 147       2  virginica
# 148       2  virginica
# 149       2  virginica

# %%
# pandas inspection

print("\n📐 Shape:",df.shape)
print("_"*50)
print()

print("n❕ Info:",df.info())
print("_"*50)
print()

print("n📊 Description:",df.describe())
print("_"*50)

# non null (no values are missing)
# Out:
# 📐 Shape: (150, 6)
# __________________________________________________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
#  5   Species            150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# n❕ Info: None
# __________________________________________________
#
# n📊 Description:        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# ...

# %%
# numpy array convertion
feature_column= iris.feature_names
X=df[feature_column]
Y=df["target"]

# %%
print(type(X))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(Y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(X)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
print(Y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
X= X.to_numpy()
Y= Y.to_numpy()

# %%
# Numpy stats (column-wise): mean, std
col_means= X.mean(axis=0)
col_stds= X.std(axis=0, ddof=0) # population std (ddof=0) degree of freedom
print("\n Numpy column means:",col_means)
print("Numpy column stds :", col_stds)
# Out:
#  Numpy column means: [5.84333333 3.05733333 3.758      1.19933333]
# Numpy column stds : [0.82530129 0.43441097 1.75940407 0.75969263]

# %%
print("Missing values in the dataset")
print(df.isnull().sum)
# Out:
# Missing values in the dataset
# <bound method DataFrame.sum of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# ...

# %%
df.groupby("Species")[feature_column].mean()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# Species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
#pair plot with seaborn

sns.set_style("whitegrid")

sns.pairplot(df[feature_column+["Species"]], hue="Species", diag_kind="kde")
plt.suptitle("Pairwise feature realtion",y=1.02)
plt.show()

# %%
feature_column+["species"]
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)',
#  'species']
